# %% [markdown]
# # Gets pages on Google News published between November 15, 2019 and December 17, 2023

# %%
import requests
from bs4 import BeautifulSoup
import csv

# First we define the search term, the number of pages we want to scrape, and the date range we want to search in.
search_term = 'Constitución Chile'
search_term = search_term.replace(' ', '+')  
num_pages = 10  
start_date = '15/11/2019'
end_date = '17/12/2023'
pages = []
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}

# Now we loop through the number of pages we want to scrape, and we extract the links from each page.
for page in range(0, num_pages):
    url = f'https://www.google.com/search?q={search_term}&tbm=nws&start={page*10}&tbs=cdr:1,cd_min:{start_date},cd_max:{end_date}'
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        links = soup.find_all('a', href=True)
        for link in links:
            href = link['href']
            if(href.startswith("/url?esrc=s&q=&rct=j&sa=U&ur")):
                link = href.split("/url?esrc=s&q=&rct=j&sa=U&url=")[1]
                pages.append(link)
                print(link)
    else:
        print(f"Error al acceder a la página {page + 1}: {response.status_code}")
# Out:
# <Response [200]>
# ...

# %% [markdown]
# # Create a .csv file

# %%
with open('pages.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    for elemento in pages:
          writer.writerow([elemento])
